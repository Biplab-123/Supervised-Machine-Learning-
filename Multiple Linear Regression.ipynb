# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.datasets import make_regression
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import plotly.graph_objects as go

# %%
#generating the data using Make_regression feature of scikit learn libary

x,y=make_regression(n_samples = 200, n_features = 2, n_informative = 2, n_targets=1 ,noise = 50)


# n_samples = Number of Rows, 
# n_features = The number of features (number of x axis)
# n_informative = The number of informative features, i.e., the number of features used to build the linear model used to generate the output.
# n_targets = The number of regression targets, i.e., the dimension of the y output vector associated with a sample. By default, the output is a scalar.
# noise = The standard deviation of the gaussian noise applied to the output

# %%
df = pd.DataFrame({'feature1':x [:,0],'feature2':x[:,1],'target':y}) #converting the data into dataframe

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -1.232934  0.614943  72.618802
# 1 -2.041661  0.963834  27.437003
# 2  1.150107 -0.872169 -39.768878
# 3 -0.442619  2.480511  34.230087
# 4 -0.142989 -0.778110 -82.929277

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature1  200 non-null    float64
#  1   feature2  200 non-null    float64
#  2   target    200 non-null    float64
# dtypes: float64(3)
# memory usage: 4.8 KB

# %%
df.tail()
# Out:
#      feature1  feature2     target
# 195 -0.109527 -0.247953  22.378608
# 196  1.553840  0.409660  59.491063
# 197 -0.372315 -0.446451  -6.291245
# 198  0.133138 -1.646606 -23.820760
# 199  0.046956  1.325333  47.484420

# %%
df.shape
# Out:
# (200, 3)

# %%
fig = px.scatter_3d(df,x='feature1',y='feature2',z='target')

# %%
#renderer='browser' use to see the graph on http://127.0.0.1:51003/ this host as this terminal is quite slow to display the data
fig.show(renderer='browser')

# %%
#Now spliting the data for training and testing 
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=3)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
print(y_pred)

#calculating the 31st index value, reshaping the value to 1 row and 2 colomn as per x_test requirement 
lr.predict(x_test[31].reshape(1,2))
# Out:
# [-26.59995991  99.39364571 -48.33123412  -3.1538491   -4.7604945
#  -16.65282383  11.49157445  -4.33176654  43.7225725   -2.80162061
#   14.28107461  45.5220754    5.6230047  -44.68127111   3.38669631
#  -15.4309418  -20.17433219  81.00387294  13.99684259  59.96131756
#   -4.98350317 -23.38318226   9.80356078   8.02142255  43.08464798
#    3.55346691  63.59076727  -4.89665078  32.42556622 -18.66813467
#    4.01353422  21.50908941 -19.76166723  20.40457008  26.23302454
#  -14.26716812 -23.28234386 -34.65887844 -32.35002156 -78.99782447]
# array([21.50908941])

# %%
#calculating the accuracy of the model here it's near 80% 

print(r2_score(y_test,y_pred))
lr.coef_
# Out:
# 0.4798224008775449
# array([18.32646378, 33.68829123])

# %%
lr.intercept_
# Out:
# 5.551319027514289

# %%
#the ouput maybe vary because of the randomness of the data,you can fix it by using the "random_state" paramenter
